# %%
from IPython.display import Image, display
import numpy as np
import cv2

from images import load_image, image_big, plot_images
from color_transfer2 import color_transfer
from color_transfer import ColorTransfer

# %%
content = cv2.imread("stylized.png")
color = cv2.imread("ny.png")

# %% [markdown]
# # Content image

# %%
image_big(content)
# Out:
# <PIL.Image.Image image mode=RGB size=512x320 at 0x7FF98E570E10>

# %% [markdown]
# # Color image

# %%
image_big(color)
# Out:
# <PIL.Image.Image image mode=RGB size=512x320 at 0x7FF98E20A320>

# %% [markdown]
# # Luminance transfer
# ### LAB

# %%
ct = ColorTransfer(content, color)

img = ct.luminance_transfer("lab")
image_big(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x320 at 0x7FF98E20A860>

# %% [markdown]
# ### LUV

# %%
img = ct.luminance_transfer("luv")
image_big(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x320 at 0x7FF98E20A898>

# %% [markdown]
# ### YUV

# %%
img = ct.luminance_transfer("yuv")
image_big(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x320 at 0x7FF98E20A6A0>

# %% [markdown]
# ### YCrCb

# %%
img = ct.luminance_transfer("ycrcb")
image_big(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x320 at 0x7FF98E20A748>
