# %%
# %matplotlib inline
from images import load_image, plot_images
from IPython.display import Image, display

# %%
Image('data/content/akali.jpg')

# %%
img = load_image('data/content/akali.jpg')
print(img.shape)

img_flattened = load_image('data/content/akali.jpg', (200, 200))
print(img_flattened.shape)
# Out:
# (717, 1215, 3)
# (118, 200, 3)

# %%
content_img = load_image('data/content/akali.jpg')
style_img = load_image('data/styles/shipwreck.jpg')
res_img = load_image('data/styles/the_scream.jpg')

plot_images(content_img, res_img, style_img)
